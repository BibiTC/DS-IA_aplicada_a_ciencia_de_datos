# %% [markdown]
# <a href="https://colab.research.google.com/github/ahcamachod/2123-ia-aplicada-a-data-science-construccion-de-visualizaciones/blob/main/IA_aplicada_a_ciencia_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <strong><font color="7b71ff">IA aplicada a Data Science: Utilizando IA en la construcción de visualizaciones de datos</font></strong>
#
#
# ---

# %% [markdown]
# <img src="https://raw.githubusercontent.com/alura-cursos/ia-datascience-dataviz/main/imagens/logos/logo_branca_fundo_azul.png" alt="inserir alt">

# %% [markdown]
# # **Clase 1 - Conociendo los datos**

# %% [markdown]
#  Zoop es una gran minorista que atiende a todas las regiones de México a través de su e-commerce. Es conocida por la amplia variedad de productos que ofrece, buscando satisfacer a todo tipo de público. Posee una serie de centros de distribución (CDs) para la entrega de sus productos, la mayoría de ellos situados en el estado de Mexico.
#
# Para gestionar su alcance, así como la facturación de su sector en tiendas online, consolida los datos en diferentes períodos de tiempo y evalúa estos datos para generar insights y tomar decisiones estratégicas en su negocio. En este proyecto, tendremos acceso a los datos de parte de su clientela de e-commerce durante el año 2023.
#
# Tú, como analista de datos de la empresa, necesitarás generar visualizaciones que ayuden en la elaboración de informes de acuerdo con algunas premisas proporcionadas por las partes interesadas, realizando un rápido análisis de la clientela que tenemos en la tienda virtual y de la facturación de la empresa.
#
# **Problema de negocio:**
#
# El equipo de datos de Zoop necesita extraer los datos y generar información a través de visuales que puedan presentarse a la directiva de la empresa, destacando los datos de facturación, perfil del cliente y otros indicadores que puedan ayudar en la toma de decisiones en su tienda online.
#
# **Base de datos**
#
# Vamos a importar dos bases de datos:
#
# Datos de los clientes del e-commerce de Zoop, separados por el código identificador de la compra.
#
# Datos de ventas del e-commerce de Zoop en 2023, separados por el código identificador de la compra.
#
# Estos datos se leerán desde el repositorio compartido en GitHub.
#
# **Desafío**
#
# Tú, como analista de datos del equipo de datos de Zoop, tienes el desafío de extraer los datos de ambas bases y construir visualizaciones que puedan agregar valor a la presentación de los resultados de Zoop en 2023. Para ello, se te presentarán 7 preguntas para que puedas contribuir en la construcción del storytelling de las ventas de la empresa.
#
# Para agilizar el proceso de análisis exploratorio de datos (AED) y la creación de visuales, utilizaremos la IA de ChatGPT como nuestra asistente, teniendo en cuenta el corto plazo para los análisis y la calidad de la entrega.

# %% [markdown]
# ## **1.2 - Obteniendo los datos**
#
# ---

# %% [markdown]
# Vamos inicialmente a proveer el link del repositorio con las dos bases que utilizaremos en el proyecto:

# %%
url_clientes = "https://gist.githubusercontent.com/ahcamachod/d08898e1cc84c7271856e78d9558ca3d/raw/2f7e1fa53711efe6433a5c5ec79948f600591cb9/clientes_zoop.csv"
url_ventas = "https://gist.githubusercontent.com/ahcamachod/966d7162a3c3a2769b8770b35abf1bcc/raw/d79941b3fa46a450f3611589abd8663399c1277b/ventas_zoop.csv"

# %% [markdown]
# Después de esta etapa, vamos a crear 2 dataframes con los datos de los clientes y de las ventas de Zoop separadamente y realizar una pequeña verificación en las tablas extraídas.

# %%
import pandas as pd
import warnings

warnings.filterwarnings('ignore') # filttra todas las advertencias colocando e parametro ignore

# %%
clientes = pd.read_csv(url_clientes)

# %%
clientes.head()
# Out:
#    ID_compra  ID_cliente            ciudad            estado    region  edad  \
# 0        904        8972  Oaxaca de Juárez            Oaxaca       Sur    49
# 1       4613        5120  Ciudad de México  Ciudad de México    Centro    49
# 2       5579        1847  Ciudad de México  Ciudad de México    Centro    24
# 3       2405        2846  Ciudad de México  Ciudad de México    Centro    38
# 4       2485        2715         Chihuahua         Chihuahua  Noroeste    30
#
#   sexo_biologico cashback  nota
# 0      Masculino       No     9
# 1       Femenino       No     9
# 2       Femenino       No     8
# 3       Femenino       Sí     7
# 4       Femenino       No    10

# %%
ventas = pd.read_csv(url_ventas)

# %%
ventas.tail()
# Out:
#       ID_compra       fecha horario            categoria  precio_unitario  \
# 6164       6141  2023-12-31   17:49    Electrodomésticos           1509.9
# 6165       6148  2023-12-31   23:02  Papelería y oficina             14.0
# 6166       6123  2023-12-31   21:25  Alimentos y bebidas             77.9
# 6167       6147  2023-12-31   21:38               Libros            142.9
# 6168       6122  2023-12-31   22:11    Belleza e higiene             89.9
#
#       cantidad   envio         metodo_pago
# 6164         5  377.48  Tarjeta de Crédito
# 6165         2    3.36       Transferencia
# 6166         1    7.79  Tarjeta de Crédito
# 6167         4   17.15  Tarjeta de Crédito
# 6168         5   13.48  Tarjeta de Crédito

# %% [markdown]
# ## **1.3 - Entendiendo los datos**
#
# ---

# %% [markdown]
# Ahora, vamos a explorar los datos comprendiendo lo que significan y cómo podemos relacionarlos en la construcción de las visualizaciones.

# %% [markdown]
# ### **Base de clientes**

# %% [markdown]
# > #### <strong><font color="7b71ff" size =6>Prompt:</font></strong>
#
# Vamos a actuar como analistas de datos de una e-commerce. Recibimos dos bases de datos con los datos de los clientes y de las ventas en 2023, respectivamente.
#
# En este primer momento, vamos a explorar la base de clientes en formato de un DataFrame de pandas, llamado "clientes". Contiene datos de los clientes que realizaron compras en la tienda virtual, siendo estos: ID de la compra, ID del cliente, la ciudad, estado y región de la compra, edad, sexo biológico, si participan en el programa de cashback y la calificación, o nota, de la compra.
#
# Queremos hacer una breve exploración de los datos para comprender un poco sobre ellos. Recordando que los datos de esta base ya están limpios y tratados. Construye el código para ejecutar esta etapa utilizando Python con el objetivo de conocer mejor el dataframe "clientes" y algunos de sus atributos.
#
# No es necesario utilizar "print()" para mostrar el resultado de las consultas.

# %%
# 1. Información general del DataFrame
print("\n[1] Información general del DataFrame:")
clientes.info()

# 2. Primeras filas para una visión inicial de los datos
print("\n[2] Primeras 5 filas del DataFrame:")
display(clientes.head())

# 3. Dimensiones del DataFrame (filas, columnas)
print("\n[3] Dimensiones del DataFrame (filas, columnas):")
print(clientes.shape)

# 4. Tipos de datos por columna
print("\n[4] Tipos de datos por columna:")
print(clientes.dtypes)

# 5. Estadísticas descriptivas para columnas numéricas
print("\n[5] Estadísticas descriptivas para columnas numéricas:")
display(clientes.describe())

# 6. Estadísticas para columnas categóricas
print("\n[6] Estadísticas para columnas categóricas:")
display(clientes.describe(include='object'))

# 7. Distribución de clientes por sexo
print("\n[7] Distribución de clientes por sexo:")
print(clientes['sexo_biologico'].value_counts())

# 8. Participación en el programa de cashback
print("\n[8] Participación en el programa de cashback:")
print(clientes['cashback'].value_counts())

# 9. Distribución de clientes por región
print("\n[9] Distribución de clientes por región:")
print(clientes['region'].value_counts())

# 10. Distribución de clientes por estado
print("\n[10] Distribución de clientes por estado:")
print(clientes['estado'].value_counts())

# 11. Número de ciudades únicas
print("\n[11] Número de ciudades únicas:")
print(clientes['ciudad'].nunique())

# 12. Verificación de valores nulos por columna
print("\n[12] Verificación de valores nulos por columna:")
print(clientes.isnull().sum())

# 13. Histograma de la edad
print("\n[13] Histograma de la edad de los clientes:")
clientes['edad'].hist(bins=20, figsize=(8,5), grid=False)

# 14. Nota promedio por sexo
print("\n[14] Nota promedio por sexo:")
print(clientes.groupby('sexo_biologico')['nota'].mean())

# 15. Nota promedio por región
print("\n[15] Nota promedio por región:")
print(clientes.groupby('region')['nota'].mean())

# 16. Nota promedio general de las compras
print("\n[16] Nota promedio general de todas las compras:")
print(round(clientes['nota'].mean(), 2))

# 17. Número de compras por cliente
print("\n[17] Número de compras por cliente (top 10):")
compras_por_cliente = clientes['ID_cliente'].value_counts()
print(compras_por_cliente.head(10))
# Out:
# [1] Información general del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6169 entries, 0 to 6168
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID_compra       6169 non-null   int64
#  1   ID_cliente      6169 non-null   int64
#  2   ciudad          6169 non-null   object
#  3   estado          6169 non-null   object
#  4   region          6169 non-null   object
#  5   edad            6169 non-null   int64
#  6   sexo_biologico  6169 non-null   object
#  7   cashback        6169 non-null   object
#  8   nota            6169 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 433.9+ KB
#
# [2] Primeras 5 filas del DataFrame:
#    ID_compra  ID_cliente            ciudad            estado    region  edad  \
# 0        904        8972  Oaxaca de Juárez            Oaxaca       Sur    49
# 1       4613        5120  Ciudad de México  Ciudad de México    Centro    49
# 2       5579        1847  Ciudad de México  Ciudad de México    Centro    24
# 3       2405        2846  Ciudad de México  Ciudad de México    Centro    38
# 4       2485        2715         Chihuahua         Chihuahua  Noroeste    30
#
#   sexo_biologico cashback  nota
# 0      Masculino       No     9
# 1       Femenino       No     9
# 2       Femenino       No     8
# 3       Femenino       Sí     7
# 4       Femenino       No    10
# [3] Dimensiones del DataFrame (filas, columnas):
# (6169, 9)
#
# [4] Tipos de datos por columna:
# ID_compra          int64
# ID_cliente         int64
# ciudad            object
# estado            object
# region            object
# edad               int64
# sexo_biologico    object
# cashback          object
# nota               int64
# dtype: object
#
# [5] Estadísticas descriptivas para columnas numéricas:
#          ID_compra   ID_cliente         edad         nota
# count  6169.000000  6169.000000  6169.000000  6169.000000
# mean   3085.000000  5461.475280    38.260010     8.443670
# std    1780.981237  2610.959977     9.838951     1.730584
# min       1.000000  1005.000000    18.000000     0.000000
# 25%    1543.000000  3148.000000    31.000000     8.000000
# 50%    3085.000000  5436.000000    38.000000     9.000000
# 75%    4627.000000  7748.000000    45.000000     9.000000
# max    6169.000000  9999.000000    70.000000    10.000000
# [6] Estadísticas para columnas categóricas:
#                   ciudad            estado  region sexo_biologico cashback
# count               6169              6169    6169           6169     6169
# unique                94                28       9              2        2
# top     Ciudad de México  Estado de México  Centro       Femenino       No
# freq                 458              1042    1540           3371     3557
# [7] Distribución de clientes por sexo:
# sexo_biologico
# Femenino     3371
# Masculino    2798
# Name: count, dtype: int64
#
# [8] Participación en el programa de cashback:
# cashback
# No    3557
# Sí    2612
# Name: count, dtype: int64
#
# [9] Distribución de clientes por región:
# region
# Centro          1540
# Noroeste        1276
# Noreste          907
# Occidente        556
# Centro-Norte     533
# Golfo            411
# Centro-Sur       383
# Sur              284
# Sureste          279
# Name: count, dtype: int64
#
# [10] Distribución de clientes por estado:
# estado
# Estado de México    1042
# Nuevo León           570
# Jalisco              478
# Ciudad de México     458
# Chihuahua            453
# Veracruz             411
# Puebla               383
# Sonora               329
# Guanajuato           284
# Coahuila             279
# Durango              263
# Oaxaca               244
# Baja California      120
# Querétaro            118
# Sinaloa              111
# Yucatán              107
# Quintana Roo          83
# Tamaulipas            58
# San Luis Potosí       54
# Tabasco               51
# Zacatecas             45
# Nayarit               43
# Chiapas               40
# Campeche              38
# Michoacán             35
# Aguascalientes        32
# Morelos               30
# Hidalgo               10
# Name: count, dtype: int64
#
# [11] Número de ciudades únicas:
# 94
#
# [12] Verificación de valores nulos por columna:
# ID_compra         0
# ID_cliente        0
# ciudad            0
# estado            0
# region            0
# edad              0
# sexo_biologico    0
# cashback          0
# nota              0
# dtype: int64
#
# [13] Histograma de la edad de los clientes:
#
# [14] Nota promedio por sexo:
# sexo_biologico
# Femenino     8.489172
# Masculino    8.388849
# Name: nota, dtype: float64
#
# [15] Nota promedio por región:
# region
# Centro          8.419481
# Centro-Norte    8.465291
# Centro-Sur      8.389034
# Golfo           8.318735
# Noreste         8.543550
# Noroeste        8.408307
# Occidente       8.456835
# Sur             8.457746
# Sureste         8.591398
# Name: nota, dtype: float64
#
# [16] Nota promedio general de todas las compras:
# 8.44
#
# [17] Número de compras por cliente (top 10):
# ID_cliente
# 5267    7
# 5145    6
# 4421    6
# 9864    6
# 9363    5
# 6698    5
# 1442    5
# 7813    4
# 3158    4
# 1648    4
# Name: count, dtype: int64

# %% [markdown]
# Depuro que necesito y que no

# %%
clientes.head()
# Out:
#    ID_compra  ID_cliente            ciudad            estado    region  edad  \
# 0        904        8972  Oaxaca de Juárez            Oaxaca       Sur    49
# 1       4613        5120  Ciudad de México  Ciudad de México    Centro    49
# 2       5579        1847  Ciudad de México  Ciudad de México    Centro    24
# 3       2405        2846  Ciudad de México  Ciudad de México    Centro    38
# 4       2485        2715         Chihuahua         Chihuahua  Noroeste    30
#
#   sexo_biologico cashback  nota
# 0      Masculino       No     9
# 1       Femenino       No     9
# 2       Femenino       No     8
# 3       Femenino       Sí     7
# 4       Femenino       No    10

# %%
clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6169 entries, 0 to 6168
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID_compra       6169 non-null   int64
#  1   ID_cliente      6169 non-null   int64
#  2   ciudad          6169 non-null   object
#  3   estado          6169 non-null   object
#  4   region          6169 non-null   object
#  5   edad            6169 non-null   int64
#  6   sexo_biologico  6169 non-null   object
#  7   cashback        6169 non-null   object
#  8   nota            6169 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 433.9+ KB

# %%
clientes.describe()
# Out:
#          ID_compra   ID_cliente         edad         nota
# count  6169.000000  6169.000000  6169.000000  6169.000000
# mean   3085.000000  5461.475280    38.260010     8.443670
# std    1780.981237  2610.959977     9.838951     1.730584
# min       1.000000  1005.000000    18.000000     0.000000
# 25%    1543.000000  3148.000000    31.000000     8.000000
# 50%    3085.000000  5436.000000    38.000000     9.000000
# 75%    4627.000000  7748.000000    45.000000     9.000000
# max    6169.000000  9999.000000    70.000000    10.000000

# %%
clientes['sexo_biologico'].value_counts()
# Out:
# sexo_biologico
# Femenino     3371
# Masculino    2798
# Name: count, dtype: int64

# %% [markdown]
# ### **Base de ventas**

# %% [markdown]
# > #### <strong><font color="7b71ff" size =6>Prompt:</font></strong>
#
# Ahora vamos explorar la base de ventas en formato de un DataFrame, llamado "ventas". Contiene datos de las ventas del comercio electrónico, que son: ID de la compra, fecha de la compra, hora de la compra, categoría del producto, precio unitario del producto, cantidad vendida, envío y el método de pago.
#
# Queremos hacer una breve exploración de los datos para comprender un poco sobre ellos. Recordando que los datos de esta base también están limpios y tratados. Construye el código para ejecutar esta etapa utilizando Python con el objetivo de conocer mejor el dataframe "clientes" y algunos de sus atributos.

# %%
# 1. Información general del DataFrame
print("\n[1] Información general del DataFrame 'ventas':")
ventas.info()

# 2. Primeras 5 filas del DataFrame
print("\n[2] Primeras 5 filas del DataFrame:")
display(ventas.head())

# 3. Dimensiones del DataFrame (filas, columnas)
print("\n[3] Dimensiones del DataFrame:")
print(ventas.shape)

# 4. Tipos de datos por columna
print("\n[4] Tipos de datos por columna:")
print(ventas.dtypes)

# 5. Estadísticas descriptivas para columnas numéricas
print("\n[5] Estadísticas descriptivas (columnas numéricas):")
display(ventas.describe())

# 6. Estadísticas para columnas categóricas
print("\n[6] Estadísticas descriptivas (columnas categóricas):")
display(ventas.describe(include='object'))

# 7. Métodos de pago disponibles
print("\n[7] Métodos de pago disponibles:")
print(ventas['metodo_pago'].value_counts())

# 8. Categorías de productos más frecuentes
print("\n[8] Categorías de productos más frecuentes:")
print(ventas['categoria'].value_counts())

# 9. Verificación de valores nulos por columna
print("\n[9] Verificación de valores nulos por columna:")
print(ventas.isnull().sum())

# 10. Precio unitario promedio
print("\n[10] Precio unitario promedio:")
print(round(ventas['precio_unitario'].mean(), 2))

# 11. Cantidad total de productos vendidos
print("\n[11] Cantidad total de productos vendidos:")
print(ventas['cantidad'].sum())

# 12. Crear columna 'valor_venta' = precio_unitario * cantidad
print("\n[12] Crear nueva columna 'valor_venta':")
ventas['valor_venta'] = ventas['precio_unitario'] * ventas['cantidad']
display(ventas[['ID_compra', 'categoria', 'valor_venta']].head())

# 13. Ingreso total del e-commerce en 2023
print("\n[13] Ingreso total del e-commerce en 2023:")
print(round(ventas['valor_venta'].sum(), 2))

# 14. Costo total de envíos
print("\n[14] Costo total de envíos:")
print(round(ventas['envio'].sum(), 2))

# 15. Ingreso total por categoría
print("\n[15] Ingreso total por categoría de producto:")
print(ventas.groupby('categoria')['valor_venta'].sum().sort_values(ascending=False))

# 16. Ingreso total por método de pago
print("\n[16] Ingreso total por método de pago:")
print(ventas.groupby('metodo_pago')['valor_venta'].sum().sort_values(ascending=False))
# Out:
# [1] Información general del DataFrame 'ventas':
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6169 entries, 0 to 6168
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID_compra        6169 non-null   int64
#  1   fecha            6169 non-null   object
#  2   horario          6169 non-null   object
#  3   categoria        6169 non-null   object
#  4   precio_unitario  6169 non-null   float64
#  5   cantidad         6169 non-null   int64
#  6   envio            6169 non-null   float64
#  7   metodo_pago      6169 non-null   object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 385.7+ KB
#
# [2] Primeras 5 filas del DataFrame:
#    ID_compra       fecha horario                    categoria  \
# 0          6  2023-01-03   20:40                 Electrónicos
# 1          5  2023-01-03   21:48  Herramientas y construcción
# 2          9  2023-01-03   17:08            Belleza e higiene
# 3          4  2023-01-03   14:29  Herramientas y construcción
# 4          8  2023-01-03   18:02            Belleza e higiene
#
#    precio_unitario  cantidad   envio         metodo_pago
# 0           4457.9         4  713.26              Paypal
# 1            115.9         1    0.00       Transferencia
# 2             68.9         2   13.78  Tarjeta de Crédito
# 3             80.9         5   40.45       Transferencia
# 4            165.0         4    0.00       Transferencia
# [3] Dimensiones del DataFrame:
# (6169, 8)
#
# [4] Tipos de datos por columna:
# ID_compra            int64
# fecha               object
# horario             object
# categoria           object
# precio_unitario    float64
# cantidad             int64
# envio              float64
# metodo_pago         object
# dtype: object
#
# [5] Estadísticas descriptivas (columnas numéricas):
#          ID_compra  precio_unitario     cantidad        envio
# count  6169.000000      6169.000000  6169.000000  6169.000000
# mean   3085.000000       873.234738     3.004863   119.233832
# std    1780.981237      1852.064342     1.420725   366.149225
# min       1.000000         2.900000     1.000000     0.000000
# 25%    1543.000000        44.900000     2.000000     0.320000
# 50%    3085.000000        93.900000     3.000000     7.550000
# 75%    4627.000000       221.900000     4.000000    29.240000
# max    6169.000000      8000.000000     5.000000  4521.540000
# [6] Estadísticas descriptivas (columnas categóricas):
#              fecha horario            categoria         metodo_pago
# count         6169    6169                 6169                6169
# unique         304     659                    8                   4
# top     2023-12-13   23:56  Alimentos y bebidas  Tarjeta de Crédito
# freq            60      26                 1495                2851
# [7] Métodos de pago disponibles:
# metodo_pago
# Tarjeta de Crédito    2851
# Transferencia         2244
# Tarjeta de Débito      547
# Paypal                 527
# Name: count, dtype: int64
#
# [8] Categorías de productos más frecuentes:
# categoria
# Alimentos y bebidas            1495
# Belleza e higiene              1062
# Casa y aseo                    1041
# Electrodomésticos               665
# Electrónicos                    580
# Papelería y oficina             551
# Herramientas y construcción     474
# Libros                          301
# Name: count, dtype: int64
#
# [9] Verificación de valores nulos por columna:
# ID_compra          0
# fecha              0
# horario            0
# categoria          0
# precio_unitario    0
# cantidad           0
# envio              0
# metodo_pago        0
# dtype: int64
#
# [10] Precio unitario promedio:
# 873.23
#
# [11] Cantidad total de productos vendidos:
# 18537
#
# [12] Crear nueva columna 'valor_venta':
#    ID_compra                    categoria  valor_venta
# 0          6                 Electrónicos      17831.6
# 1          5  Herramientas y construcción        115.9
# 2          9            Belleza e higiene        137.8
# 3          4  Herramientas y construcción        404.5
# 4          8            Belleza e higiene        660.0
# [13] Ingreso total del e-commerce en 2023:
# 16243454.0
#
# [14] Costo total de envíos:
# 735553.51
#
# [15] Ingreso total por categoría de producto:
# categoria
# Electrónicos                   10547410.0
# Electrodomésticos               4351368.5
# Belleza e higiene                423262.9
# Casa y aseo                      316688.6
# Herramientas y construcción      252953.1
# Alimentos y bebidas              231284.3
# Libros                            75265.0
# Papelería y oficina               45221.6
# Name: valor_venta, dtype: float64
#
# [16] Ingreso total por método de pago:
# metodo_pago
# Tarjeta de Crédito    7437061.8
# Transferencia         5985372.9
# Paypal                1599706.0
# Tarjeta de Débito     1221313.3
# Name: valor_venta, dtype: float64

# %% [markdown]
# Valido que datos necesito

# %%
ventas.head()
# Out:
#    ID_compra       fecha horario                    categoria  \
# 0          6  2023-01-03   20:40                 Electrónicos
# 1          5  2023-01-03   21:48  Herramientas y construcción
# 2          9  2023-01-03   17:08            Belleza e higiene
# 3          4  2023-01-03   14:29  Herramientas y construcción
# 4          8  2023-01-03   18:02            Belleza e higiene
#
#    precio_unitario  cantidad   envio         metodo_pago  valor_venta
# 0           4457.9         4  713.26              Paypal      17831.6
# 1            115.9         1    0.00       Transferencia        115.9
# 2             68.9         2   13.78  Tarjeta de Crédito        137.8
# 3             80.9         5   40.45       Transferencia        404.5
# 4            165.0         4    0.00       Transferencia        660.0

# %%
# 1. Información general del DataFrame
print("\n[1] Información general del DataFrame 'ventas':")
ventas.info()
# Out:
# [1] Información general del DataFrame 'ventas':
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6169 entries, 0 to 6168
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID_compra        6169 non-null   int64
#  1   fecha            6169 non-null   object
#  2   horario          6169 non-null   object
#  3   categoria        6169 non-null   object
#  4   precio_unitario  6169 non-null   float64
#  5   cantidad         6169 non-null   int64
#  6   envio            6169 non-null   float64
#  7   metodo_pago      6169 non-null   object
#  8   valor_venta      6169 non-null   float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 433.9+ KB

# %%
# 5. Estadísticas descriptivas para columnas numéricas
print("\n[5] Estadísticas descriptivas (columnas numéricas):")
display(ventas.describe())
# Out:
# [5] Estadísticas descriptivas (columnas numéricas):
#          ID_compra  precio_unitario     cantidad        envio   valor_venta
# count  6169.000000      6169.000000  6169.000000  6169.000000   6169.000000
# mean   3085.000000       873.234738     3.004863   119.233832   2633.077322
# std    1780.981237      1852.064342     1.420725   366.149225   6300.467095
# min       1.000000         2.900000     1.000000     0.000000      2.900000
# 25%    1543.000000        44.900000     2.000000     0.320000    104.500000
# 50%    3085.000000        93.900000     3.000000     7.550000    263.600000
# 75%    4627.000000       221.900000     4.000000    29.240000    746.700000
# max    6169.000000      8000.000000     5.000000  4521.540000  39884.500000

# %%
# 17. Conversión de la columna 'fecha' a tipo datetime
print("\n[0] Conversión de la columna 'fecha' a datetime:")
ventas['fecha'] = pd.to_datetime(ventas['fecha'], format='%Y-%m-%d')
print(ventas['fecha'].dtypes)
# Out:
# [0] Conversión de la columna 'fecha' a datetime:
# datetime64[ns]

# %%
display(ventas.describe())
# Out:
#          ID_compra                          fecha  precio_unitario  \
# count  6169.000000                           6169      6169.000000
# mean   3085.000000  2023-08-20 00:12:22.292105984       873.234738
# min       1.000000            2023-01-03 00:00:00         2.900000
# 25%    1543.000000            2023-05-30 00:00:00        44.900000
# 50%    3085.000000            2023-08-31 00:00:00        93.900000
# 75%    4627.000000            2023-11-23 00:00:00       221.900000
# max    6169.000000            2023-12-31 00:00:00      8000.000000
# std    1780.981237                            NaN      1852.064342
#
#           cantidad        envio   valor_venta
# count  6169.000000  6169.000000   6169.000000
# mean      3.004863   119.233832   2633.077322
# min       1.000000     0.000000      2.900000
# 25%       2.000000     0.320000    104.500000
# 50%       3.000000     7.550000    263.600000
# 75%       4.000000    29.240000    746.700000
# max       5.000000  4521.540000  39884.500000
# std       1.420725   366.149225   6300.467095

# %% [markdown]
# ## **1.4 - Tipos de gráficos**
#
# ---

# %% [markdown]
# Ya hemos explorado un poco de las dos bases del proyecto y obtuvimos algunos insights interesantes que pueden ser importantes en la construcción de nuestras visualizaciones.
#
# Ahora, intentemos simplificar nuestro análisis consolidando los datos en una única tabla para, a partir de ahí, enfocarnos en las posibilidades de visuales combinando los datos. ¿Podrá GPT ayudarnos aquí?

# %% [markdown]
# > #### <strong><font color="7b71ff" size =6>Prompt:</font></strong>
#
# Ahora vamos a unir las dos bases de nuestro proyecto en una sola utilizando como llave la columna "ID_compra". Además, organizaremos las columnas en la siguiente secuencia:
#
# * ID_compra
# * fecha
# * horario
# * categoria
# * precio_unitario
# * cantidad
# * envio
# * metodo_pago
# * ID_cliente
# * edad
# * sexo_biologico
# * ciudad
# * estado
# * region
# * cashback
# * nota
#
# Construye un código para ejecutar esta etapa usando Python y la biblioteca Pandas.

# %%
# Los Dataframe clientes y ventas ya estan cargados

# 1. Unir los DataFrames 'ventas' y 'clientes' por la columna 'ID_compra'
print("\n[1] Uniendo DataFrames por 'ID_compra'...")
df = pd.merge(ventas, clientes, on='ID_compra', how='inner')

# 2. Verificar cantidad de registros después de la unión
print("\n[2] Dimensiones del DataFrame combinado:")
print(df.shape)

# 3. Reorganizar columnas en el orden especificado
orden_columnas = [
    'ID_compra', 'fecha', 'horario', 'categoria',
    'precio_unitario', 'cantidad', 'envio', 'metodo_pago',
    'ID_cliente', 'edad', 'sexo_biologico', 'ciudad',
    'estado', 'region', 'cashback', 'nota'
]

df = df[orden_columnas]

# 4. Mostrar las primeras filas del DataFrame final
print("\n[3] Primeras filas del DataFrame combinado y ordenado:")
display(df.head())
# Out:
# [1] Uniendo DataFrames por 'ID_compra'...
#
# [2] Dimensiones del DataFrame combinado:
# (6169, 17)
#
# [3] Primeras filas del DataFrame combinado y ordenado:
#    ID_compra      fecha horario                    categoria  precio_unitario  \
# 0          6 2023-01-03   20:40                 Electrónicos           4457.9
# 1          5 2023-01-03   21:48  Herramientas y construcción            115.9
# 2          9 2023-01-03   17:08            Belleza e higiene             68.9
# 3          4 2023-01-03   14:29  Herramientas y construcción             80.9
# 4          8 2023-01-03   18:02            Belleza e higiene            165.0
#
#    cantidad   envio         metodo_pago  ID_cliente  edad sexo_biologico  \
# 0         4  713.26              Paypal        6149    30      Masculino
# 1         1    0.00       Transferencia        9491    36      Masculino
# 2         2   13.78  Tarjeta de Crédito        5288    39       Femenino
# 3         5   40.45       Transferencia        9679    35      Masculino
# 4         4    0.00       Transferencia        1380    50      Masculino
#
#              ciudad            estado        region cashback  nota
# 0        Hermosillo            Sonora      Noroeste       Sí    10
# 1  Ciudad de México  Ciudad de México        Centro       Sí     8
# 2    Aguascalientes    Aguascalientes  Centro-Norte       No     7
# 3          Veracruz          Veracruz         Golfo       Sí     9
# 4  Ciudad de México  Ciudad de México        Centro       No     9

# %% [markdown]
# Ahora le pediremos a ChatGPT ideas de visuales que podamos contruir con esos datos

# %% [markdown]
# > #### <strong><font color="7b71ff" size =6>Prompt:</font></strong>
#
# Ahora con nuestro "df" ya construido a partir de las dos bases del proyecto, vamos a iniciar un nuevo proceso. Queremos comenzar la etapa de generación de visuales que puedan ayudar en el análisis de la facturación a lo largo del año, el perfil del cliente y otros datos que puedan ser relevantes para el análisis y la construcción de nuestra narrativa.
#
# Las columnas de "df" son:
#
# * ID_compra: número único asignado a la compra realizada, en formato int
# * fecha: fecha de la compra, en formato datetime
# * horario: hora de la compra, en formato object
# * categoria: categoría del producto, en formato object
# * precio_unitario: precio de una unidad del producto, en formato float
# * cantidad: cantidad vendida del producto, en formato int
# * envio: costo de envío a ser pagado en total de la compra, en formato float
# * metodo_pago: método de pago de la compra, en formato object
# * ID_cliente: número único asignado al cliente, en formato int
# * edad: edad del cliente, en formato int
# * sexo_biologico: sexo biológico del cliente, en formato object
# * ciudad: ciudad del cliente, en formato object
# * estado: estado del cliente, en formato object
# * region: región del cliente, en formato object
# * cashback: si el cliente participa o no en el programa de cashback de la tienda, en formato object
# * nota: evaluación del cliente por la compra, en formato int
#
# El objetivo es abstraer y buscar relaciones para construir visualizaciones interesantes para el análisis de los datos de los clientes y ventas de Zoop.
#
# Con base en la información proporcionada, ¿qué tipos de visualizaciones serían útiles para alcanzar el objetivo de analizar los datos?

# %% [markdown]
# ---
#
# ---
#
# ##📊 **Sugerencias de visualizaciones útiles para el análisis de ventas y perfil del cliente en Zoop**
#
# ¡Gracias, Bibiana! Ya revisé las imágenes que compartiste y a partir de ellas he estructurado las **sugerencias de visualización** exactamente en ese formato: numeradas, con títulos, tipo de gráfico sugerido, una breve explicación y con foco claro en cómo cada visual ayuda a interpretar los datos del e-commerce **Zoop**.
#
# ---
#
# ## ✅ Sugerencias de Visualizaciones de Zoop
#
# Para construir una narrativa sólida a partir de los datos de ventas y clientes de Zoop, se pueden realizar varias visualizaciones que te ayuden a explorar la facturación, el perfil de los clientes, las relaciones entre variables y las tendencias de comportamiento. A continuación te presento las visualizaciones agrupadas por enfoque analítico:
#
# ---
#
# ### 1. Análisis de Facturación a lo Largo del Año:
#
# * **📈 Gráfico de líneas de facturación mensual:**
#   Permite visualizar cómo evoluciona la facturación mes a mes durante el año. Se puede usar la columna `fecha` agrupada por mes y calcular el ingreso total (`precio_unitario * cantidad + envio`). Esto ayuda a identificar patrones estacionales o meses con menor rendimiento.
#
# * **📊 Gráfico de barras por categoría:**
#   Muestra la facturación generada por cada categoría de producto. Es útil para saber cuáles son los productos más rentables y tomar decisiones sobre inventario, promoción y foco de ventas.
#
# * **🗓️🔥 Mapa de calor de días y horas de mayor facturación:**
#   Utilizando las columnas `fecha` y `horario`, este gráfico muestra en qué días de la semana y en qué horarios se generan más ventas. Ayuda a definir estrategias de marketing según los momentos de mayor actividad.
#
# ---
#
# ### 2. Perfil del Cliente:
#
# * **📊 Histograma de edades:**
#   Visualiza la distribución de edades de los clientes. Te permite identificar qué grupos etarios son más frecuentes y enfocar estrategias de comunicación y diseño de productos para ellos.
#
# * **⚖️ Gráfico circular o de barras del sexo biológico:**
#   Muestra la proporción de clientes masculinos y femeninos (`sexo_biologico`). Es útil para comprender el perfil demográfico de los compradores.
#
# * **📍 Gráfico de barras por región:**
#   Permite ver cuántos clientes provienen de cada región del país (`region`). Así puedes entender mejor la distribución geográfica de tu mercado y decidir dónde enfocar campañas regionales.
#
# * **💸 Gráfico de barras por participación en el programa de cashback:**
#   Analiza cuántos clientes participan en el programa de cashback (`cashback`). También puedes cruzar esta variable con la `nota` para evaluar su efecto sobre la satisfacción.
#
# ---
#
# ### 3. Relaciones entre Datos:
#
# * **🔘 Gráfico de dispersión (scatterplot) de precio unitario vs cantidad:**
#   Permite observar si hay una relación entre el precio de los productos y la cantidad que se vende. Ayuda a detectar productos de alto volumen o premium.
#
# * **📦 Gráfico de cajas (boxplot) de las notas por método de pago:**
#   Muestra si hay diferencias en la evaluación de la compra según el método de pago (`metodo_pago`). Es útil para descubrir problemas en ciertas pasarelas de pago.
#
# * **🧾 Gráfico de barras apiladas de método de pago por región:**
#   Visualiza la preferencia de métodos de pago en distintas regiones. Ayuda a adaptar las opciones de pago a las preferencias locales.
#
# ---
#
# ### 4. Análisis Temporal y de Ciclos:
#
# * **📅 Gráfico de barras por día de la semana:**
#   Revela en qué días se realizan más ventas. Puede servir para lanzar ofertas específicas según el comportamiento semanal de los clientes.
#
# * **📊 Gráfico de barras de la evaluación promedio por mes:**
#   Permite analizar cómo cambia la satisfacción de los clientes a lo largo del año (evaluación promedio o `nota`). Es útil para detectar periodos donde la experiencia puede mejorar.
#
# ---
#
# ### 5. Análisis de Métodos de Pago:
#
# * **🥧 Gráfico de torta del método de pago:**
#   Muestra la distribución del uso de métodos de pago por parte de los clientes. Permite detectar preferencias generales y tomar decisiones sobre alianzas o promociones específicas.
#
# * **📊 Gráfico de barras de la facturación total por método de pago:**
#   Revela cuál método de pago genera más ingresos. Esta información puede usarse para negociar tarifas con plataformas de pago o enfocar campañas según la rentabilidad.
#
# ---
#
# ### 6. Segmentación del Cliente:
#
# * **👥 Gráfico de barras de cantidad de compras por cliente:**
#   Muestra cuántos clientes son compradores frecuentes y cuántos solo compraron una vez. Ayuda a identificar oportunidades para programas de fidelización o campañas de recompra.
#
# * **📊 Análisis de correlación con mapa de calor:**
#   Usando un heatmap de correlaciones, puedes ver relaciones entre variables como edad, nota, cantidad comprada, método de pago, cashback, etc. Esto ayuda a descubrir patrones o perfiles de cliente valiosos.
#
# ---
#
# Estas visualizaciones te permitirán entender mejor el comportamiento de los clientes, identificar oportunidades comerciales y tomar decisiones estratégicas más informadas para mejorar la experiencia de compra y aumentar la rentabilidad de Zoop.
#
# ---

# %% [markdown]
# # **Clase 2 - Visualizando los dados**

# %% [markdown]
# ChatGPT trajo algunas ideas interesantes para la creación de los gráficos.
#
# Sin embargo, como ya tenemos algunas preguntas para guiarnos en la creación de los visuales, no vamos a seguir todas las sugerencias aquí mencionadas.
#
# Queda como una sugerencia para ayudarte cuando estés trabajando con otras bases y tengas dificultades para pensar en qué visualizaciones podrías construir.
#
# **Observación:** Recordando que es muy probable que los gráficos que se me señalaron, no sean necesariamente los mismos que aparecerán para ti, dado a la aleatoriedad de las respuestas de cualquier IA generativa.

# %% [markdown]
# ## **2.1 - Definiendo los visualizaciones**
#
# ---

# %% [markdown]
# Después de la etapa de exploración de los datos, vamos a leer las preguntas que se plantearon en la demanda que recibimos. Así, comenzaremos a pensar en los visuales que vamos a construir con la ayuda de la IA.
#
# ### **Preguntas**
#
# #### Ventas
#
# 1. ¿Cuáles fueron los métodos de pago más utilizados en 2023?
# 2. ¿Cuál fue la facturación por categoría en 2023?
# 3. ¿Cómo fueron las ventas a lo largo de los meses en 2023?
# 4. ¿Cómo se divide la venta por trimestre por método de pago? ¿Existe un período en que algún tipo de pago se destaca?
#
#
# #### Perfil del cliente
#
# 5. ¿Cuál es la proporción de la clientela que participa en nuestro programa de cashback?
# 6. ¿Cómo están distribuidas las evaluaciones del producto? ¿Tenemos buenos números generales?
# 7. ¿Cómo se distribuye nuestro público por edad y sexo biológico? ¿Existe un grupo que se destaca?
#
# Inicialmente, vamos a hacer la primera versión de los gráficos, aún no refinados con los elementos visuales, para más adelante ir añadiendo las diversas técnicas de storytelling.

# %% [markdown]
# ### **1ra Pregunta:** ¿Cuáles fueron los métodos de pago más utilizados en 2023?

# %% [markdown]
# Le vamos pedir a ChatGPT que nos auxilie en la construcción de este visual. Primero, trataremos los datos generando una tabla resumida (que también es una especie de visual) y luego construiremos el primer gráfico.

# %% [markdown]
# > #### <strong><font color="7b71ff" size=6>Prompt:</font></strong>
#
# Tenemos un DataFrame llamado "df" y queremos construir un visual que presente cuáles métodos de pago fueron los más utilizados.
#
# En "df", tenemos la columna "metodo_pago" con los 4 tipos de pago utilizados en la compra.
#
# Inicialmente, queremos construir una tabla llamada "metodos_de_pago" que resuma los datos de esta columna y, a continuación, deseamos crear una visualización que muestre la cantidad de esos métodos de pago presentes en la tabla "metodo_pago".
#
# Utiliza las bibliotecas de visualización de datos de Python para crear esta visualización.

# %%
# Crear la tabla resumen
metodos_de_pago = df['metodo_pago'].value_counts().reset_index()
metodos_de_pago.columns = ['Metodo de Pago', 'Cantidad']
metodos_de_pago
# Out:
#        Metodo de Pago  Cantidad
# 0  Tarjeta de Crédito      2851
# 1       Transferencia      2244
# 2   Tarjeta de Débito       547
# 3              Paypal       527

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Estilo de gráfico
sns.set(style="whitegrid")

# Crear gráfico de barras
plt.figure(figsize=(8, 5))
sns.barplot(data=metodos_de_pago, x='Metodo de Pago', y='Cantidad', palette='Set2')

# Títulos y etiquetas
plt.title('Cantidad de Compras por Método de Pago', fontsize=14)
plt.xlabel('Método de Pago')
plt.ylabel('Cantidad de Compras')
plt.xticks(rotation=45)
plt.tight_layout()

# Mostrar gráfico
plt.show()

# %% [markdown]
# 📝 Análisis sugerido – Compras por Método de Pago
# El gráfico de barras presenta la distribución de las compras según el método de pago utilizado por los clientes.
#
# Se puede observar que el método de pago más utilizado fue [nombre del método más alto], lo cual puede estar asociado a su facilidad de uso, confianza del cliente o posibles beneficios como acumulación de puntos o cashback.
#
# En contraste, métodos como [nombre del método menos usado] presentan una baja participación, lo que puede ser resultado de menor adopción tecnológica o falta de incentivos promocionales.
#
# Esta información es fundamental para tomar decisiones estratégicas, como reforzar la promoción de Zoop Pay o de métodos con menos participación, analizar la fricción en el proceso de pago o ajustar la UX para favorecer métodos más rentables para la empresa.

# %%
# Gráfico de torta
plt.figure(figsize=(6, 6))
plt.pie(metodos_de_pago['Cantidad'], labels=metodos_de_pago['Metodo de Pago'], autopct='%1.1f%%', colors=sns.color_palette('Set2'))
plt.title('Distribución de Métodos de Pago')
plt.show()

# %% [markdown]
# <font color="7b71ff" size=4> Comentarios: </font>
#
# ---
#
# Podemos observar que, incluso sin especificar el tipo de gráfico, por la forma en que presentamos los datos a ChatGPT, logró representar con éxito un visual que muestra la información deseada. Un gráfico de barras es realmente ideal para representar las cantidades de una o más categorías de datos.
#
# Iremos ajustando poco a poco los visuales para que se adecuen a nuestro público y reflejen la identidad visual de la empresa.

# %% [markdown]
# ## **2.2 - Comparando los datos**
#
# ---

# %% [markdown]
# ### **2da Pregunta:** ¿Cuál fue la facturación por categoria em 2023?

# %% [markdown]
# **Observación:** Para la facturación, consideraremos aquí el producto entre el precio unitario y la cantidad, sumados al costo de envío de cada producto.

# %% [markdown]
# > #### <strong><font color="7b71ff" size=6>Prompt:</font></strong>
#
# Tenemos un DataFrame llamado "df" y queremos construir un gráfico de barras horizontales que muestre la facturación por categoría de Zoop.
#
# En "df", tenemos las siguientes columnas:
# * categoria: categorías de los productos
# * precio_unitario: precio de una unidad del producto
# * cantidad: cantidad vendida del producto
# * envio: costo de envío total de la compra.
#
# Deseamos crear una visualización que muestre la facturación de cada categoría, donde la facturación se calcula multiplicando el precio unitario por la cantidad y sumando el costo de envío.
#
# Utiliza las bibliotecas de visualización de datos de Python para crear esta visualización.

# %%
df.head()
# Out:
#    ID_compra      fecha horario                    categoria  precio_unitario  \
# 0          6 2023-01-03   20:40                 Electrónicos           4457.9
# 1          5 2023-01-03   21:48  Herramientas y construcción            115.9
# 2          9 2023-01-03   17:08            Belleza e higiene             68.9
# 3          4 2023-01-03   14:29  Herramientas y construcción             80.9
# 4          8 2023-01-03   18:02            Belleza e higiene            165.0
#
#    cantidad   envio         metodo_pago  ID_cliente  edad sexo_biologico  \
# 0         4  713.26              Paypal        6149    30      Masculino
# 1         1    0.00       Transferencia        9491    36      Masculino
# 2         2   13.78  Tarjeta de Crédito        5288    39       Femenino
# 3         5   40.45       Transferencia        9679    35      Masculino
# 4         4    0.00       Transferencia        1380    50      Masculino
#
#              ciudad            estado        region cashback  nota
# 0        Hermosillo            Sonora      Noroeste       Sí    10
# 1  Ciudad de México  Ciudad de México        Centro       Sí     8
# 2    Aguascalientes    Aguascalientes  Centro-Norte       No     7
# 3          Veracruz          Veracruz         Golfo       Sí     9
# 4  Ciudad de México  Ciudad de México        Centro       No     9

# %%
# ✅ PASO 1: Calcular la facturación por categoría
# Crear nueva columna con facturación por compra
df['facturacion'] = (df['precio_unitario'] * df['cantidad']) + df['envio']

# Agrupar por categoría y sumar la facturación
facturacion_categoria = df.groupby('categoria')['facturacion'].sum().reset_index()

# Ordenar de mayor a menor
facturacion_categoria = facturacion_categoria.sort_values(by='facturacion', ascending=True)

# %%
#✅ PASO 2: Gráfico de barras horizontales
import matplotlib.pyplot as plt
import seaborn as sns

# Estilo
sns.set(style="whitegrid")

# Crear gráfico
plt.figure(figsize=(10, 6))
sns.barplot(data=facturacion_categoria, x='facturacion', y='categoria', palette='viridis', orient='h')

# Títulos y etiquetas
plt.title('Facturación por Categoría de Producto', fontsize=14)
plt.xlabel('Facturación Total')
plt.ylabel('Categoría')
plt.tight_layout()

# Mostrar gráfico
plt.show()

# %% [markdown]
# <font color="7b71ff" size=4> Comentarios: </font>
#
# ---
#
# Aquí especificamos el tipo de gráfico, guiando a ChatGPT en la creación de nuestro visual. Podemos notar que en un gráfico de barras el enfoque está más centrado en las categorías, además de ser una forma más fluida de leer textos que podrían ser demasiado extensos para un gráfico de columnas.

# %% [markdown]
# ### **3a Pregunta:** ¿Cómo fueron las ventas a lo largo de los meses en 2023?

# %% [markdown]
# > #### <strong><font color="7b71ff" size=6>Prompt:</font></strong>
#
# Tenemos un DataFrame llamado "df" y queremos construir un gráfico de líneas que muestre las ventas totales mensuales de Zoop.
#
# En "df", tenemos las siguientes columnas:
# * fecha: con las fechas de las compras en formato datetime (`aaaa-mm-dd`)
# * facturación: calculada como el producto del precio unitario y la cantidad, sumado al costo de envío de cada venta.
#
# Deseamos crear una visualización que muestre las ventas por mes. Primero, agrupa los datos por mes y luego crea una nueva columna llamada "mes" que contenga el nombre de cada mes, traduciendo los meses del índice mediante el siguiente diccionario. Utiliza la columna "fecha" para agrupar los datos y construir el gráfico. La columna "mes" solo debe usarse para cambiar las etiquetas del eje x.
#
# ```
# meses = {
#     'January': 'Ene',
#     'February': 'Feb',
#     'March': 'Mar',
#     'April': 'Abr',
#     'May': 'May',
#     'June': 'Jun',
#     'July': 'Jul',
#     'August': 'Ago',
#     'September': 'Sep',
#     'October': 'Oct',
#     'November': 'Nov',
#     'December': 'Dic'
# }
# ```
#
#
# Utiliza las bibliotecas de visualización de datos de Python para crear esta visualización.

# %%
# Supongamos que ya se ha calculado la columna 'facturacion'

# 1. Crear una nueva columna 'mes' que extrae el mes de la columna 'fecha'
df['mes'] = df['fecha'].dt.month_name()

# 2. Agrupar los datos por mes y calcular la facturación total mensual
ventas_mensuales = df.groupby(df['fecha'].dt.to_period('M'))['facturacion'].sum().reset_index()

# 3. Convertir el periodo de fecha a tipo datetime para mantener formato de fecha
ventas_mensuales['fecha'] = ventas_mensuales['fecha'].dt.to_timestamp()

# 4. Crear una columna de nombre del mes en español usando el diccionario proporcionado
meses = {
    'January': 'Ene',
    'February': 'Feb',
    'March': 'Mar',
    'April': 'Abr',
    'May': 'May',
    'June': 'Jun',
    'July': 'Jul',
    'August': 'Ago',
    'September': 'Sep',
    'October': 'Oct',
    'November': 'Nov',
    'December': 'Dic'
}

ventas_mensuales['mes'] = ventas_mensuales['fecha'].dt.month_name().map(meses)

# 5. Crear el gráfico de líneas de ventas mensuales
plt.figure(figsize=(10, 6))
sns.lineplot(x='mes', y='facturacion', data=ventas_mensuales, marker='o', sort=False)

# 6. Añadir etiquetas y título
plt.title('Ventas Totales Mensuales de Zoop', fontsize=16)
plt.xlabel('Mes', fontsize=12)
plt.ylabel('Facturación Total', fontsize=12)

# 7. Mostrar el gráfico
plt.show()

# %% [markdown]
# <font color="7b71ff" size=4> Comentarios: </font>
#
# ---
#
# Cuando tenemos una cantidad mayor de períodos en nuestros datos, vale la pena recurrir a gráficos de líneas, que son ideales para series temporales. Dado que nuestros datos son mensuales, utilizar un gráfico de columnas, por ejemplo, reduciría la percepción de la secuencia de los datos. Las líneas ofrecen una mayor sensación de continuidad.
#
# Siéntete libre de formular algunas hipótesis sobre los momentos de alta y baja en las compras.

# %% [markdown]
# ##**2.3 - Componiendo datos dinámicos**

# %% [markdown]
# Construimos algunos visuales interesantes para comparar los datos, mostrando las facturaciones de Zoop. Ahora, pasemos a una nueva categoría de visuales: composición.
#
# Vamos a hacer una composición dinámica de los datos. Para ello, añadiremos más variables al análisis, incorporando 3 variables diferentes, siendo una de ellas categórica.

# %% [markdown]
# ###**4a Pregunta:** ¿Cómo está dividida la venta por trimestre por método de pago? ¿Existe algún período en el que algún tipo de pago se destaque?

# %% [markdown]
# > #### <strong><font color="7b71ff" size=6>Prompt:</font></strong>
#
# Tenemos un DataFrame llamado "df" y queremos construir un gráfico de barras apiladas que muestre las ventas por trimestre en relación con el método de pago de Zoop.
#
# En "df", tenemos las siguientes columnas:
# * fecha: con las fechas de las compras en formato datetime (`aaaa-mm-dd`)
# * facturacion: con los valores de las ventas
# * metodo_pago: con el método de pago elegido en la compra
#
# Deseamos crear una visualización que muestre las ventas por trimestre, agrupando los métodos de pago de cada trimestre correspondientes a cada compra.
#
# Utiliza las bibliotecas de visualización de datos de Python para crear esta visualización.

# %%
#✅ Paso 1: Crear columna de trimestre
import pandas as pd

# Asegurar que la columna 'fecha' esté en formato datetime
df['fecha'] = pd.to_datetime(df['fecha'])

# Crear nueva columna con el trimestre en formato '2023Q1', '2023Q2', etc.  Q es quarter - 1 trimestre
df['trimestre'] = df['fecha'].dt.to_period('Q').astype(str)

# %%
#✅ Paso 2: Agrupar por trimestre y método de pago
# Agrupar ventas por trimestre y método de pago  - metodo unstack desapila
ventas_trimestrales = df.groupby(['trimestre', 'metodo_pago'])['facturacion'].sum().unstack(fill_value=0)
#ventas_trimestrales

#Esto genera una tabla con:
#Filas = trimestres
#Columnas = métodos de pago
#Celdas = total facturado por método de pago en ese trimestre

# %%
# La misma informacion pero todo unificado y facilita visualizacion
#ventas_trimestrales.unstack()

# %%
#✅ Paso 3: Crear gráfico de barras apiladas
import matplotlib.pyplot as plt

# Crear el gráfico
ventas_trimestrales.plot(
    kind='bar',
    stacked=True,
    figsize=(10, 6),
    colormap='Set2'
)

# Títulos y etiquetas
plt.title('Ventas Trimestrales por Método de Pago', fontsize=14)
plt.xlabel('Trimestre')
plt.ylabel('Facturación Total')
plt.xticks(rotation=45)
plt.legend(title='Método de Pago', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

# Mostrar gráfico
plt.show()
#✅ Resultado

#Verás un gráfico con:
#Una barra por trimestre
#Cada barra apilada por los distintos métodos de pago
#El eje Y indica la facturación total

# %% [markdown]
# <font color="7b71ff" size=4> Comentarios: </font>
#
# ---
#
# El gráfico de columnas apiladas añade a la comparación entre períodos o categorías, la comparación también entre los datos de cada período/categoría. Es como si pusiéramos una "lupa" en cada columna y visualizáramos la composición de cada una de acuerdo con la variable deseada (aquí, las formas de pago).
#
# Siéntete libre de formular algunas hipótesis sobre las ventas por trimestre combinadas con el tipo de pago y qué ideas podemos obtener de esta base de datos.

# %% [markdown]
# #**Clase 3 - Componiendo datos estáticos**

# %% [markdown]
# ## **3.1 - Componiendo datos estáticos**
#
# ---

# %% [markdown]
# Inicialmente, presentaremos un ejemplo de cómo podemos utilizar la **comparación de datos estáticos**, es decir, un recorte en el tiempo o de las variables que poseemos.

# %% [markdown]
# ### **5ª Pregunta:** ¿Cuál es la proporción de la clientela que participa en nuestro programa de cashback?

# %% [markdown]
# > #### <strong><font color="7b71ff" size=6>Prompt:</font></strong>
#
# Tenemos un DataFrame llamado "df" y queremos construir un gráfico que muestre la proporción de usuarios(as) que están participando en el programa de cashback de Zoop.
#
# En "df", tenemos la columna "cashback" que contiene estos datos.
#
# Utiliza las bibliotecas de visualización de datos de Python para crear esta visualización.

# %% [markdown]
# RTA CHAT GPT:
# Para visualizar la proporción de usuarios que participan en el programa de cashback de Zoop, puedes usar un gráfico de torta o un gráfico de barras, ambos muy útiles para mostrar proporciones.
#
# Aquí tienes el paso a paso usando pandas y matplotlib:

# %%
#✅ Paso 1: Crear la tabla resumen de participación en cashback

# Contar la cantidad de usuarios que participan o no en el programa de cashback
participacion_cashback = df['cashback'].value_counts().reset_index()
participacion_cashback.columns = ['Participa', 'Cantidad']

# %%
#✅ Opción A: Gráfico de torta (ideal para proporciones)
import matplotlib.pyplot as plt

# Crear gráfico de torta
plt.figure(figsize=(6, 6))
plt.pie(participacion_cashback['Cantidad'],
        labels=participacion_cashback['Participa'],
        autopct='%1.1f%%',
        colors=['#66c2a5', '#fc8d62'],
        startangle=90)

# Título
plt.title('Participación en el Programa de Cashback de Zoop')
plt.axis('equal')  # Asegura que sea un círculo perfecto
plt.show()

# %%
#✅ Opción B: Gráfico de barras (más claro para comparar cantidades)
import seaborn as sns

# Crear gráfico de barras
plt.figure(figsize=(6, 4))
sns.barplot(data=participacion_cashback, x='Participa', y='Cantidad', palette='Set2')

# Títulos y etiquetas
plt.title('Cantidad de Usuarios que Participan en Cashback')
plt.xlabel('¿Participa en Cashback?')
plt.ylabel('Cantidad de Usuarios')
plt.tight_layout()
plt.show()

# %% [markdown]
# ✅ Resultado
# Ambas opciones te permitirán ver fácilmente la proporción entre usuarios que sí y que no participan en el programa de cashback.

# %% [markdown]
# > #### <strong><font color="7b71ff" size =6>Prompt:</font></strong>
#
# ¿Podrías utilizar el color rojo y mantener el azul y cambiar el gráfico anterior a uno tipo rosquilla?
#
# Utiliza las bibliotecas de visualización de datos de Python para crear esta visualización.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Paso 1: Crear la tabla resumen de participación en cashback
participacion_cashback = df['cashback'].value_counts().reset_index()
participacion_cashback.columns = ['Participa', 'Cantidad']

# Paso 2: Crear gráfico tipo rosquilla
colors = ['#66c2a5', '#e74c3c']  # verde y rojo

plt.figure(figsize=(6, 6))
# Crear gráfico tipo pastel
wedges, texts, autotexts = plt.pie(
    participacion_cashback['Cantidad'],
    labels=participacion_cashback['Participa'],
    autopct='%1.1f%%',
    startangle=90,
    colors=colors,
    wedgeprops={'width': 0.4}  # Esto convierte el pastel en rosquilla
)

# Centro blanco
plt.gca().add_artist(plt.Circle((0, 0), 0.6, color='white'))

# Título
plt.title('Participación en el Programa de Cashback de Zoop')
plt.axis('equal')  # Asegura que sea un círculo
plt.tight_layout()
plt.show()

# %% [markdown]
# 🎨 ¿Qué hace este código?
# Usa una rosquilla en lugar de un pastel.
#
# Colores: verde suave para quienes participan y rojo intenso para quienes no.
#
# Muestra los porcentajes de forma clara y estética.

# %% [markdown]
# PROMPT Por favor invertir los colores para mejor visualización

# %% [markdown]
# ##Aprendiendo mas:
#
# Antes construimos un gráfico de columnas apiladas para la composición de datos con el apoyo del ChatGPT. ¿Qué te parece si aprendemos también otro tipo de visualización que combine la composición y comparación de datos a través de un problema?
#
# La directiva de Zoop está preocupada por las categorías con menor facturación anual en su e-commerce y, por eso, le gustaría entender el desempeño de esas categorías de manera aislada. Para esto, recibimos la demanda de explorar la facturación trimestral investigando cómo está el equilibrio de estas ventas por cada categoría.
#
# Para resolver este problema, vamos a agrupar las 3 categorías con las menores facturaciones anuales, separándolas por trimestre mediante un gráfico de columnas agrupadas.
#
# ¿Por qué un gráfico de columnas agrupadas?
#
# Un gráfico de columnas agrupadas es ideal para comparar categorías diferentes en relación con una variable (puede ser temporal o no), mostrando cómo los valores se comparan dentro de cada categoría en columnas separadas, facilitando la visualización de patrones y diferencias entre grupos.
#
# A continuación, vamos a pedir ayuda al ChatGPT para construir esta visualización mediante el siguiente prompt:
#
# Tenemos un DataFrame llamado "df" y queremos construir una visualización de un gráfico de columnas agrupadas lado a lado que presente las ventas por trimestre en relación con las categorías de los productos.
#
# En "df", tenemos las columnas:
#
# trimestre: con las fechas en trimestres de las compras
# faturamento: con los valores de las ventas
# categoria: con las categorías de los productos vendidos. Vamos a utilizar solo las categorías "Papelería y oficina", "Libros" y "Alimentos y bebidas".
# Deseamos crear una visualización que presente las ventas por trimestre ("facturacion"), agrupando las categorías lado a lado en relación con el trimestre correspondiente a cada compra.
#
# Utiliza las bibliotecas de visualización de datos de Python para crear esta visualización."""
#
# El código generado por el prompt fue el siguiente:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Filtrar solo las categorías de interés
categorias_objetivo = ['Papelería y oficina', 'Libros', 'Alimentos y bebidas']
df_filtrado = df[df['categoria'].isin(categorias_objetivo)]

# Agrupar por trimestre y categoría, sumando la facturación
ventas_trimestrales = df_filtrado.groupby(['trimestre', 'categoria'])['facturacion'].sum().reset_index()

# Crear el gráfico
plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")

# Usar gráfico de columnas agrupadas
sns.barplot(data=ventas_trimestrales, x='trimestre', y='facturacion', hue='categoria', palette='Set2')

# Agregar títulos y etiquetas
plt.title('Ventas por Trimestre y Categoría de Producto', fontsize=14)
plt.xlabel('Trimestre')
plt.ylabel('Facturación Total')
plt.legend(title='Categoría')
plt.tight_layout()

# Mostrar gráfico
plt.show()

# %% [markdown]
# <font color="7b71ff" size=4> Comentarios: </font>
#
# ---
#
# ¡Mira eso! Una vez más, la IA nos presentó una buena idea de qué gráfico aplicar para este caso, pero ¿notaste que "ella" no tiene idea de los datos que poseemos?
#
# Debemos estar atentos a esto, ya que solo le proporcionamos los nombres de las columnas y los datos que había allí. La IA no puede saber si un valor es positivo o negativo, por ejemplo. Por eso, el "no" estaba en azul y el "sí" en verde. En el siguiente prompt, le indicamos que sustituyera el color verde por el rojo (sin mencionar el valor real de los datos) y pedimos una modificación en el visual.
#
# ¿Qué tal si experimentas hacer otros pedidos y ves cómo se comporta ChatGPT?
#
# Hablando del gráfico, los gráficos de sectores son ideales para pocas categorías de datos, preferiblemente datos dicotómicos (2 categorías, como sí y no, gato y perro...). Representan la proporción de los datos de manera estática.

# %% [markdown]
# ## **3.2 - Distribuyendo Datos**
#
# ---

# %% [markdown]
# Con la ayuda de la IA, generaremos más gráficos que serán importantes para la construcción del storytelling del informe de Zoop, según lo solicitado. Ahora, partiendo de la distribución de datos, vamos a analizar el perfil de los clientes y cómo evalúan sus compras en Zoop.

# %% [markdown]
# ### **6ª Pregunta:** ¿Cómo están distribuidas las calificaciones de la compra? ¿Tenemos buenos números en general?

# %% [markdown]
# Vamos a pedirle a ChatGPT que nos ayude a construir este visual. Veamos si esta IA puede representar estos datos con un visual adecuado.

# %% [markdown]
# > #### <strong><font color="7b71ff" size=6>Prompt:</font></strong>
#
# Tenemos un DataFrame llamado "df" y queremos construir un gráfico que muestre la distribución de las evaluaciones del público en relación con las compras realizadas en la tienda online.
#
# En "df", tenemos la columna "nota" con las calificaciones otorgadas por cada usuario en relación con la compra que realizaron, que varían de 0 a 10 en números enteros.
#
# Deseamos crear una visualización que muestre la distribución de estos datos.
#
# Utiliza las bibliotecas de visualización de datos de Python para crear este gráfico.

# %% [markdown]
# RTA: CHAT GPT
#
# Para analizar la distribución de las evaluaciones (columna nota) de los usuarios de la tienda online, lo ideal es usar un:
#
# Histograma (para ver la frecuencia de cada calificación)
#
# o un gráfico de violín o boxplot si quieres ver la forma de la distribución más detalladamente.
#
# Aquí te dejo una opción con histograma, ideal para este tipo de análisis:

# %%
#✅ Visualización: Histograma de notas de evaluación

import matplotlib.pyplot as plt
import seaborn as sns

# Estilo visual
sns.set(style="whitegrid")

# Crear histograma
plt.figure(figsize=(8, 5))
sns.histplot(data=df, x='nota', bins=11, kde=False, color='#7b71ff')

# Títulos y etiquetas
plt.title('Distribución de Calificaciones de los Clientes', fontsize=14)
plt.xlabel('Nota (de 0 a 10)')
plt.ylabel('Cantidad de Evaluaciones')
plt.xticks(range(0, 11))  # Asegura que los valores estén de 0 a 10
plt.tight_layout()

plt.show()

# %% [markdown]
# ✅ ¿Qué muestra este gráfico?
# Cuántos clientes dieron cada nota (ej. cuántos pusieron 10, cuántos pusieron 7, etc.)
#
# Te permite detectar patrones: si predominan las notas altas, o si hay muchas notas bajas que deban investigarse.

# %% [markdown]
# <font color="7b71ff" size=4> Comentarios: </font>
#
# ---
#
# Una vez más, no necesitamos especificar directamente el tipo de gráfico, ya que al mencionar la distribución de valores numéricos de una simple columna, ChatGPT logró interpretar y proporcionar el código para un histograma de columnas. Este gráfico es ideal para presentar la distribución de una muestra de datos o población. Cada columna aquí representa la frecuencia de repetición de un valor.
#
# ¿Te gustaría experimentar haciendo lo mismo solo con las edades?

# %% [markdown]
# ### **7ª Pregunta:** ¿Cómo está distribuida nuestra audiencia por edad y sexo biológico? ¿Existe algún grupo que sobresalga?

# %% [markdown]
# > #### <strong><font color="7b71ff" size=6>Prompt:</font></strong>
#
# Tenemos un DataFrame llamado "df" y queremos construir un gráfico que muestre la distribución de nuestra audiencia por edad y sexo biológico.
#
# En "df", tenemos las columnas:
# * edad: edad de la persona que realizó la compra
# * sexo_biologico: sexo biológico de la persona que realizó la compra, con datos categóricos
#
# Deseamos crear una visualización que muestre la distribución de estos datos.
#
# Utiliza las bibliotecas de visualización de datos de Python para crear esta visualización.

# %%
#✅ Opción A: Histograma por edad y sexo biológico (comparativo)

import matplotlib.pyplot as plt
import seaborn as sns

# Estilo visual
sns.set(style="whitegrid")

# Crear histograma agrupado por sexo biológico
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='edad', hue='sexo_biologico', bins=20, kde=False, palette='Set2', multiple='stack')

# Títulos y etiquetas
plt.title('Distribución de Edad por Sexo Biológico', fontsize=14)
plt.xlabel('Edad')
plt.ylabel('Cantidad de Clientes')
plt.tight_layout()

plt.show()

# %%
#✅ Opción B: Gráfico de densidad por sexo biológico (más suave y comparativo)

plt.figure(figsize=(10, 5))
sns.kdeplot(data=df, x='edad', hue='sexo_biologico', fill=True, palette='Set2', alpha=0.5)

# Títulos y etiquetas
plt.title('Distribución de Edad por Sexo Biológico (Densidad)', fontsize=14)
plt.xlabel('Edad')
plt.ylabel('Densidad')
plt.tight_layout()

plt.show()

# %% [markdown]
# 🔍 ¿Qué puedes descubrir con estos gráficos?
# Si hay más mujeres u hombres en ciertos rangos de edad.
#
# En qué edades se concentra la mayoría de tu audiencia.
#
# Si tu audiencia es joven, adulta o más distribuida.

# %% [markdown]
# <font color="7b71ff" size=4> Comentarios: </font>
#
# ---
# El gráfico generado es poco práctico, ya que compila los datos del sexo biológico 'Masculino' y 'Femenino' en el gráfico de violín. Necesitamos darle una instrucción adicional a GPT para elegir un visual más adecuado.

# %% [markdown]
# > #### <strong><font color="7b71ff" size=6>Prompt:</font></strong>
#
# Creo que podemos mejorar este gráfico. ¿Qué te parece cambiar a un boxplot?

# %% [markdown]
# RESULTADO PROMP:
#
# Un boxplot (diagrama de caja) es ideal si quieres visualizar de forma clara:
#
# La mediana de edad por sexo biológico
#
# La dispersión (rango intercuartílico)
#
# Y posibles valores atípicos (outliers)
#
# Esto te permitirá comparar rápidamente cómo varía la edad entre los distintos grupos de sexo biológico.

# %%
#✅ CÓDIGO PARA BOXPLOT: Edad vs Sexo Biológico

import matplotlib.pyplot as plt
import seaborn as sns

# Estilo del gráfico
sns.set(style="whitegrid")

# Crear el boxplot
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='sexo_biologico', y='edad', palette='Set2')

# Títulos y etiquetas
plt.title('Distribución de Edad por Sexo Biológico', fontsize=14)
plt.xlabel('Sexo Biológico')
plt.ylabel('Edad')
plt.tight_layout()
plt.show()

# %% [markdown]
# 📝 Análisis sugerido – Distribución de edad por sexo biológico
# El gráfico de caja (boxplot) presenta la distribución de edades de los clientes que realizaron compras en la tienda online, segmentados por sexo biológico.
#
# A través de esta visualización es posible observar las diferencias entre los grupos:
#
# La mediana de edad se encuentra en un rango similar para ambos sexos, lo que indica una audiencia con características etarias relativamente homogéneas.
#
# Sin embargo, el rango intercuartílico y la presencia de valores atípicos muestran que hay una mayor dispersión de edades en el grupo de [indicar si aplica: mujeres / hombres], con una participación más marcada de personas en edades extremas.
#
# Este tipo de análisis permite comprender mejor el perfil de la audiencia, lo cual es fundamental para ajustar el tono de comunicación, la selección de productos promocionados y la segmentación en campañas de marketing digital.
#
# Además, entender cómo varía la edad por grupo de sexo biológico puede ayudar a diseñar estrategias personalizadas y más efectivas.

# %% [markdown]
# <font color="7b71ff" size=4> Comentarios: </font>
#
# ---
#
# Esta vez fue necesario guiar a la IA para generar una visualización mejor para nuestros análisis.
#
# El gráfico representado es un boxplot (diagrama de caja) que es ideal para representar un conjunto de datos de acuerdo con 5 medidas de interés: valor máximo, mínimo, 1º cuartil (donde están situados el 25% de los datos), 2º cuartil o mediana (donde están situados el 50% de los datos) y 3º cuartil (donde están situados el 75% de los datos).
#
# ¿Recuerdas el `describe()`? Este gráfico presenta en un solo elemento gran parte de los datos que la función muestra en tabla.
#
# Concluimos la 1ª versión de los 7 visuales que utilizaremos en nuestro proyecto. Ahora, pasaremos a la aplicación de las técnicas de storytelling para mejorar los visuales y adaptarlos a la identidad visual de Zoop antes de la exportación.
